# %% [markdown]
# <html>
#   <body>
#     <h2>Decision Tree Assignment Report</h2>
#     <h4>This section provides a brief summary report on some of the important conclusions regarding decision tree</h4>
#   </body>
# </html>

# %% [markdown]
# <html>
#   <body>
#       <p>The training set comprised of the following attributes broadly ranging across two types</p>
#       <ul>
#         <li>Numerical
#           <ol>
#             <li>satisfaction_level</li>
#             <li>last_evaluation</li>
#             <li>number_project</li>
#             <li>average_montly_hours</li>
#             <li>time_spend_company</li>
#           </ol>
#         </li>
#         <li>Categorical
#           <ol>
#             <li>Work_accident</li>
#             <li>promotion_last_5years</li>
#             <li>sales</li>
#           </ol>
#         </li>
#       </ul>
#       <p>The categorical and numerical attributes have been dealt with separately, each with different kind of data pre-processing.</p>
#       <p>The categorical data requires to special pre-processing or cleaning up, because categorical data can be trained in decision trees very intuitively.</p>
#       <p>Numerical data on the other hand can be dealt with several ways two of which are the following: </p>
#       <ol>
#         <li><b>Binary Splitting</b>: Entire data set is split into ranges according to impurity and at each level of the tree, one range can be checked. A branch is taken if the range condition is satisfied and other branch is taken if the range condition is not satisfied.</li>
#         <li><b>Conversion to range cateogry</b>: Entire data set is split into ranges according to impurity and before training the data, the each of the value of numerical data is substituted by the range to which it belongs to. That way it can be converted to categorical data which can be used to form n-ary trees.</li>
#       </ol>
#       <p>In this assignment, the latter approach is used as it gives an intuitive approach in building trees.</p>
#   </body>
# </html>

# %% [markdown]
# <html>
#   <body>
#     <p>The following are the ranges for different numerical columns in our data split according to maximum entropy</p>
#     <dl>
#       <dt>satisfaction_level</dt>
#       <dd><=0.17, 0.18 to 0.29, 0.30 to 0.39, 0.40 to 0.46, 0.47 to 0.53, 0.54 to 0.6, 0.61 to 0.67, 0.68 to 0.74, 0.75 to 0.8, 0.81 to 0.87, 0.88 to 0.94, >0.94</dd>
#       <dt>last_evaluation</dt>
#       <dd><=0.44, 0.45 to 0.51, 0.52 to 0.58, 0.59 to 0.65, 0.66 to 0.71, 0.72 to 0.78, 0.79 to 0.86, 0.87 to 0.93, >0.93</dd>
#       <dt>number_project</dt>
#       <dd><=3, >3</dd>
#       <dt>average_montly_hours</dt>
#       <dd><=173, 174 to 229, >229</dd>
#       <dt>time_spend_company</dt>
#       <dd><=3, >3 and <=6, >6</dd>
#     </dl>
#   </body>
# </html>

# %% [markdown]
# <html>
#   <body>
#     <h3>Data Visualisation</h3>
#     <p>Let us visualise the data given comparing some numerical attributes with each other, according to range to which they belong to.</p>
#   </body>
# </html>

# %% [markdown]
# <html>
#   <body>
#     <table>
#       <tr>
#         <td><img src="vis_1.png"></td>
#         <td><img src="vis_2.png"></td>
#         <td><img src="vis_3.png"></td>
#       </tr>
#     </table>
#   </body>
# </html>

# %% [markdown]
# <html>
#   <body>
#     <h3>Train algorithm</h3>
#     <p>The following is the algorithm used to build the tree (train the model)</p>
#     <ol>
#       <li>Input data</li>
#       <li>Compute impurities (entropy) of all columns</li>
#       <li>Compute Average entropy of all columns with the following formula</li>
#       $$I(S,A) = \sum_{i}^{ }\frac{|{S_{i}}^{ }|}{|S|}\cdot E({S_{i}}^{ })$$
#       <li>Compute Gain of columns using the following formula</li>
#       $$G(S,A) = E(S) - I(S,A)$$
#       <li>If no more Gain is left to compute, declare leaf node and fill corresponding result value</li>
#       <li>Find the column with maximum gain and make it a node</li>
#       <li>For each category of column with maximum Gain, repeat from step 2</li>
#     </ol>
#   </body>
# </html>

# %% [markdown]
# <html>
#   <body>
#     <h3>Impurity Function</h3>
#     <p>The impurity function is used to check if the distribution of positive and negative results are almost equal for the attributes under question. We have compared the performance of three kinds of impurity functions.</p>
#     <ul>
#       <li>Entropy
#         <br>
#         $$E = -(qlogq + (1-q)log(1-q))$$
#         <br>
#       </li>
#       <li>Gini
#         <br>
#         $$E = 2q(1-q)$$
#         <br>
#       </li>
#       <li>Misclassification Rate
#         <br>
#         $$E = min(q,1-q)$$
#         <br>
#       </li>
#     </ul>
#   </body>
# </html>

# %% [markdown]
# <html>
#   <body>
#     <h3>Accuracy</h3>
#     <p>The accuracy has been calculated, first with training just categorical data and then training with numerical and categorical data.</p>
#     <p>The below are accuracies reported for both of the above criteria: </p>
#     <dl>
#       <dt>Categorical Attributes only</dt>
#       <dd>Train Accuracy : 76.1624026696</dd>
#       <dd>Test Accuracy : 76.5569395018</dd>
#       <dt>Numerical and Categorical Attributes</dt>
#       <dd>Train Accuracy : 98.8876529477</dd>
#       <dd>Test Accuracy : 96.4857651246</dd>
#     </dl>
#     <p>As we can see, there is no sign of overfitting and underfitting because the test and train error are almost equal.</p>
#     <p>Accuracy has also been calculated according the impurity function that has been used to train the data. Here are the results</p>
#     <dl>
#       <dt>Entropy</dt>
#       <dd>Train Accuracy: 98.8876529477</dd>
#       <dd>Test Accuracy: 96.4857651246</dd>
#       <dt>Gini Index</dt>
#       <dd>Train Accuracy: 98.8876529477</dd>
#       <dd>Test Accuracy: 96.4857651246</dd>
#       <dt>Misclassification rate</dt>
#       <dd>Train Accuracy: 98.8876529477</dd>
#       <dd>Test Accuracy: 96.4857651246</dd>
#     </dl>
#     <p>As we can observe from above data, the accuracy is almost equal among all impurity functions.</p>
#     <p>The accuracy has also been compared according the depth of the tree and number of nodes in tree. The results of which are illustrated using the graphs below.</p>
#     <table>
#       <tr>
#         <td><img src="acc_1.png"></td>
#         <td><img src="acc_2.png"></td>
#       </tr>
#     </table>
#     <p>On the left image, x-axis represents depth(height) of the tree and y-axis represents the accuracy</p>
#     <p>On the right image, x-axis represents number of nodes in the tree and y-axis represents the accuracy</p>
#   </body>
# </html>

# %% [markdown]
# <html>
#   <body>
#     <h3>Precision, Recall, F1 Score</h3>
#     <p>Precision, Recall and F1 Score are performance metrics used to explain how much of false positives and false negatives is made by the model.</p>
#     <p>Precision, recall and F1 score are computed using the following formula: </p>
#     <br>
#     $$Precision = \frac{True Positive}{True Positive + False Positive}$$
#     <br>
#     $$Recall = \frac{True Positive}{True Positive + False Negative}$$
#     <br>
#     $$F1 Score = \frac{2}{\frac{1}{Recall} + \frac{1}{Precision}}$$
#     <br>
#     <p>The Precision, recall and F1 Score has been calculated, first with training just categorical data and then training with numerical and categorical data.</p>
#     <dl>
#       <h4>Categorical Attributes only</h4>
#       <dt>Train Set</dt>
#       <dd>Precision : 0.75</dd>
#       <dd>Recall : 0.00279459711225</dd>
#       <dd>F1 Score : 0.00556844547564</dd>
#       <dt>Test Set</dt>
#       <dd>Precision : 1.0</dd>
#       <dd>Recall : 0.00189393939394</dd>
#       <dd>F1 Score : 0.00378071833648</dd>
#       <h4>Numerical and Categorical Attributes</h4>
#       <dt>Train Set</dt>
#       <dd>Precision : 0.957941834452</dd>
#       <dd>Recall : 0.997205402888</dd>
#       <dd>F1 Score : 0.977179370151</dd>
#       <dt>Test Set</dt>
#       <dd>Precision : 0.937621832359</dd>
#       <dd>Recall : 0.910984848485</dd>
#       <dd>F1 Score : 0.924111431316</dd>
#     </dl>
#     <p>The Precision, recall and F1 Score has been calculated according to impurity function.</p>
#     <dl>
#       <h4>Entropy</h4>
#       <dt>Train set</dt>
#       <dd>Precision : 0.957941834452</dd>
#       <dd>Recall : 0.997205402888</dd>
#       <dd>F1 Score : 0.977179370151</dd>
#       <dt>Test Set</dt>
#       <dd>Precision : 0.937621832359</dd>
#       <dd>Recall : 0.910984848485</dd>
#       <dd>F1 Score : 0.924111431316</dd>
#       <h4>Gini Index</h4>
#       <dt>Train Set</dt>
#       <dd>Precision : 0.957941834452</dd>
#       <dd>Recall : 0.997205402888</dd>
#       <dd>F1 Score : 0.977179370151</dd>
#       <dt>Test Set</dt>
#       <dd>Precision : 0.937621832359</dd>
#       <dd>Recall : 0.910984848485</dd>
#       <dd>F1 Score : 0.924111431316</dd>
#       <h4>Misclassification Rate</h4>
#       <dt>Train Set</dt>
#       <dd>Precision : 0.957941834452</dd>
#       <dd>Recall : 0.997205402888</dd>
#       <dd>F1 Score : 0.977179370151</dd>
#       <dt>Test Set</dt>
#       <dd>Precision : 0.937621832359</dd>
#       <dd>Recall : 0.910984848485</dd>
#       <dd>F1 Score : 0.924111431316</dd>
#     </dl>
#   </body>
# </html>
